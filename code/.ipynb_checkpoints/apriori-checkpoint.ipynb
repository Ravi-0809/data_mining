# %%
import ast
import os
import sys
import time

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
project_home = os.path.join("../")
sys.path.append(project_home)
data_path = os.path.join(project_home, "data/merged_preprocessed.csv")

# %%
from lib.apriori import runApriori

# %%
df = pd.read_csv(data_path, encoding="latin1")

# %%
len(df)
# Out:
# 375197

# %%
df.columns
# Out:
# Index(['college_name', 'levell', 'programme', 'discipline_group', 'discipline',
#        'type', 'year', 'total_general_total', 'total_general_females',
#        'total_backward_castes_total', 'total_backward_castes_females',
#        'total_total_persons', 'total_total_females', 'pwd_general_total',
#        'pwd_general_females', 'pwd_backward_castes_total',
#        'pwd_backward_castes_females', 'pwd_total_persons', 'pwd_total_females',
#        'muslim_minority_general_total', 'muslim_minority_general_females',
#        'muslim_minority_backward_castes_total',
#        'muslim_minority_backward_castes_females',
#        'muslim_minority_total_persons', 'muslim_minority_total_females',
#        'other_minority_general_total', 'other_minority_general_females',
#        'other_minority_backward_castes_total',
#        'other_minority_backward_castes_females',
#        'other_minority_total_persons', 'other_minority_total_females', 'state',
#        'city', 'speciality', 'girl_exclusive', 'student_hostel_available'],
#       dtype='object')

# %% [markdown]
# ### Converting to required dataset format

# %%
columns_set_1 = ["levell", "programme", "total_general_total", "total_backward_castes_total", "pwd_total_persons", 
                "muslim_minority_total_persons", "other_minority_total_persons"
                ]
columns_set_2 = ["programme", "total_general_females", "total_backward_castes_females", "pwd_total_females",
                 "muslim_minority_total_females", "other_minority_total_females"
                ]

# %%
def binning(columns, df, bins=[(0,0.2), (0.2,0.5), (0.5,1.01)]):
    for column in columns:
        for bin_interval in bins:
            name = column + " [{}-{}]".format(bin_interval[0], bin_interval[1])
            df[name] = (df[column] >= bin_interval[0]) & (df[column] < bin_interval[1])
        df.drop(column, axis=1, inplace=True)
    
    return df

# %%
def one_hot_enc(column_name, df):
    d = pd.get_dummies(df[column_name])
    df = pd.concat([d, df], axis=1)
    df.drop(column_name, axis=1, inplace=True)
    return df

# %%
def convert_to_apriori_dataset(apriori_df, non_bool_cols = ["level", "programme"], 
                               bool_col_names=["general", "BC", "PWD", "muslim", "other"]):
    new_df = apriori_df[non_bool_cols]
    apriori_df.drop(columns=non_bool_cols, axis=1, inplace=True)
    new_col = apriori_df.apply(lambda x: apriori_df.columns[x].tolist(), axis=1)
    new_col = pd.DataFrame(new_col.tolist(), columns = bool_col_names)
    new_df = pd.concat([new_df, new_col], axis=1)
    
    return new_df

# %%
apriori_df = df[columns_set_1].copy()
apriori_df.columns = ["level", "programme", "general", "BC", "PWD", "muslim", "other"]

# %%
cols = ["general", "BC", "PWD", "muslim", "other"]
bins = [(0, 0.2), (0.2,0.5), (0.5,0.7), (0.7,1.01)]
apriori_df = binning(cols, apriori_df, bins)

# %%
apriori_df.head()
# Out:
#             level                                 programme  general [0-0.2]  \
# 0  Under Graduate                 B.Sc.-Bachelor of Science            False
# 1  Under Graduate            B.Tech.-Bachelor of Technology            False
# 2  Under Graduate  B.C.A.-Bachelor of Computer Applications            False
# 3  Under Graduate       B.H.M.-Bachelor of Hotel Management            False
# 4  Under Graduate          B.P.T.-Bachelor of Physiotherapy            False
#
#    general [0.2-0.5]  general [0.5-0.7]  general [0.7-1.01]  BC [0-0.2]  \
# 0               True              False               False       False
# 1              False              False                True        True
# 2              False              False                True        True
# 3              False              False                True        True
# 4              False               True               False       False
#
#    BC [0.2-0.5]  BC [0.5-0.7]  BC [0.7-1.01]  ...  PWD [0.5-0.7]  \
# 0         False          True          False  ...          False
# 1         False         False          False  ...          False
# 2         False         False          False  ...          False
# 3         False         False          False  ...          False
# 4          True         False          False  ...          False
#
#    PWD [0.7-1.01]  muslim [0-0.2]  muslim [0.2-0.5]  muslim [0.5-0.7]  \
# 0           False            True             False             False
# 1           False            True             False             False
# 2           False            True             False             False
# 3           False            True             False             False
# 4           False            True             False             False
#
#    muslim [0.7-1.01]  other [0-0.2]  other [0.2-0.5]  other [0.5-0.7]  \
# 0              False           True            False            False
# 1              False           True            False            False
# 2              False           True            False            False
# 3              False           True            False            False
# 4              False           True            False            False
#
#    other [0.7-1.01]
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 22 columns]

# %%
non_bool_cols = ["level", "programme", "state", "speciality"]
bool_col_names = ["general", "BC", "PWD", "muslim", "other"]

# %%
# %%time
apriori_df = convert_to_apriori_dataset(apriori_df)
# Out:
# CPU times: user 29.5 s, sys: 24.9 ms, total: 29.5 s
# Wall time: 29.6 s

# %%
extra_df = df[["state", "speciality", "girl_exclusive", "student_hostel_available"]].copy()

# %%
extra_df["girl_exclusive"] = extra_df["girl_exclusive"].apply(lambda x: "Girl_exclusive" if x else "Co-ed")
extra_df["student_hostel_available"] = extra_df["student_hostel_available"].apply(
    lambda x: "Hostel_available" if x else "No_hostel"
)
extra_df["speciality"] = extra_df["speciality"].replace({'0': "No speciality"})

# %%
apriori_df = pd.concat([apriori_df, extra_df], axis=1)
del extra_df

# %%
apriori_df
# Out:
#                  level                                          programme  \
# 0       Under Graduate                          B.Sc.-Bachelor of Science
# 1       Under Graduate                     B.Tech.-Bachelor of Technology
# 2       Under Graduate           B.C.A.-Bachelor of Computer Applications
# 3       Under Graduate                B.H.M.-Bachelor of Hotel Management
# 4       Under Graduate                   B.P.T.-Bachelor of Physiotherapy
# ...                ...                                                ...
# 375192  Under Graduate                          B.Sc.-Bachelor of Science
# 375193  Under Graduate  M.B.B.S.-Bachelor of Medicine and Bachelor of ...
# 375194   Post Graduate                            M.D.-Doctor of Medicine
# 375195  Under Graduate                              B.A.-Bachelor of Arts
# 375196  Under Graduate                        B.Com.-Bachelor of Commerce
#
#                    general             BC          PWD          muslim  \
# 0        general [0.2-0.5]   BC [0.5-0.7]  PWD [0-0.2]  muslim [0-0.2]
# 1       general [0.7-1.01]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
# 2       general [0.7-1.01]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
# 3       general [0.7-1.01]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
# 4        general [0.5-0.7]   BC [0.2-0.5]  PWD [0-0.2]  muslim [0-0.2]
# ...                    ...            ...          ...             ...
# 375192     general [0-0.2]  BC [0.7-1.01]  PWD [0-0.2]  muslim [0-0.2]
# 375193   general [0.5-0.7]   BC [0.2-0.5]  PWD [0-0.2]  muslim [0-0.2]
# 375194     general [0-0.2]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
# 375195  general [0.7-1.01]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
# 375196  general [0.7-1.01]     BC [0-0.2]  PWD [0-0.2]  muslim [0-0.2]
#
#                 other          state                speciality  \
# 0       other [0-0.2]  Uttar Pradesh             No speciality
# 1       other [0-0.2]    West Bengal  Engineering & Technology
# 2       other [0-0.2]        Gujarat      Computer Application
# 3       other [0-0.2]    West Bengal             No speciality
# 4       other [0-0.2]        Gujarat             Physiotherapy
# ...               ...            ...                       ...
# 375192  other [0-0.2]  Uttar Pradesh             No speciality
# 375193  other [0-0.2]        Haryana         Medical-Allopathy
# 375194  other [0-0.2]        Haryana         Medical-Allopathy
# 375195  other [0-0.2]  Uttar Pradesh             No speciality
# 375196  other [0-0.2]         Punjab             No speciality
#
#         girl_exclusive student_hostel_available
# 0                Co-ed                No_hostel
# 1                Co-ed                No_hostel
# 2                Co-ed         Hostel_available
# 3                Co-ed                No_hostel
# 4                Co-ed         Hostel_available
# ...                ...                      ...
# 375192           Co-ed                No_hostel
# 375193           Co-ed         Hostel_available
# 375194           Co-ed         Hostel_available
# 375195           Co-ed                No_hostel
# 375196  Girl_exclusive         Hostel_available
#
# [375197 rows x 11 columns]

# %% [markdown]
# ### Frequent pattern and rule gen

# %%
def data_generator(df):
    for idx in range(len(df)):
        record = frozenset(df.iloc[idx])
        yield record

# %%
data = data_generator(apriori_df)

# %%
data

# %%
# %%time
items, rules = runApriori(data, minSupport=0.15, minConfidence=0.6)

# %%
sorted(items, key=lambda x: x[1], reverse=True)

# %%
sorted(rules, key=lambda x: x[1], reverse=True)

# %%
rules_list = []
for rule in rules:
    rules_list.append({
        "precedent": rule[0][0],
        "antecendent": rule[0][1],
        "confidence": rule[1]
    })
rules_df = pd.DataFrame(rules_list)

# %%
rules_df.to_csv("../results/apriori_latest.csv", index=False)

# %% [markdown]
# ### Lift calculation

# %%
full_set = apriori_df.values

# %%
super_set = []
for row in full_set:
    super_set.append(set(row))

# %%
del full_set

# %%
super_set
# Out:
# [{'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Computer Application',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.H.M.-Bachelor of Hotel Management',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.P.T.-Bachelor of Physiotherapy',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Physiotherapy',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.D.-Doctor of Medicine',
#   'Medical-Allopathy',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Punjab',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'M.D.-Doctor of Medicine',
#   'Medical-Allopathy',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Punjab',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Punjab',
#   'Technical',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.H.M.S.-Bachelor of Homeopathic Medicine and Surgery',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'Medical-Homeopathy',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'PWD [0-0.2]',
#   'Pharm.D.-Doctor of Pharmacy',
#   'Pharmacy',
#   'Post Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0.5-0.7]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'Nursing',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Architecture',
#   'B.Architecture-Bachelor of Architecture',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Pharm.D.-Doctor of Pharmacy',
#   'Pharmacy',
#   'Post Graduate',
#   'Telangana',
#   'general [0.7-1.01]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Commerce',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.H.M.C.T.-Bachelor of Hotel Management and Catering Technology',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Himachal Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'M.B.A.- Master of Business Administration',
#   'Management',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Punjab',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No_hostel',
#   'Others',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Science',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Telangana',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Gujarat',
#   'M.E.-Master of Engineering',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Technical',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A. L.L.B.-Bachelor of Arts, Bachelor of Law or Laws',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Integrated',
#   'Law',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Agriculture',
#   'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.5-0.7]',
#   'Engineering & Technology',
#   'Girl_exclusive',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'M.Com.-Master of Commerce',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0.2-0.5]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0-0.2]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Andhra Pradesh',
#   'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Pharm.-Bachelor of Pharmacy',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Pharmacy',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'L.L.B.-Bachelor of Law or Laws',
#   'Law',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Gujarat',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'Nursing',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.P.Ed.-Bachelor of Physical Education',
#   'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'M.A.-Master of Arts',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Maharashtra',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Technical',
#   'Telangana',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Education/Teacher Education',
#   'Gujarat',
#   'M.Ed. -Master of Education',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.B.A.-Bachelor of Business Administration',
#   'BC [0-0.2]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Shastri-Shastri',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'D.Ed.-Diploma in Education',
#   'Diploma',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Chhatisgarh',
#   'Diploma',
#   'Diploma-Diploma',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Diploma',
#   'Diploma-Diploma',
#   'Engineering & Technology',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Diploma',
#   'Diploma-Diploma',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'M.Pharm. -Master of Pharmacy',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Pharm.-Bachelor of Pharmacy',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.B.A.-Bachelor of Business Administration',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.5-0.7]',
#   'other [0-0.2]'},
#  {'Andhra Pradesh',
#   'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Telangana',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Tech. -Master of Technology',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Rajasthan',
#   'Technical',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.B.M.-Bachelor of Business Management',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'Integrated',
#   'Integrated M.Sc.-Integrated Master of Science',
#   'No speciality',
#   'PWD [0-0.2]',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.B.A.-Bachelor of Business Administration',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.Pharm.-Bachelor of Pharmacy',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Pharmacy',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Ed.-Bachelor of Education',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Architecture',
#   'B.Architecture-Bachelor of Architecture',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Shastri-Shastri',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.M.M.-Bachelor of Multi Media',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Commerce',
#   'Gujarat',
#   'Hostel_available',
#   'M.Com.-Master of Commerce',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.P.T.-Master of Physiotherapy',
#   'PWD [0-0.2]',
#   'Physiotherapy',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Diploma',
#   'Diploma-Diploma',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.B.A.- Master of Business Administration',
#   'Management',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Technical',
#   'Telangana',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'Nursing',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'PWD [0-0.2]',
#   'Sanskrit',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Bihar',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Certificate',
#   'Certificate-Certificate',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.B.A.-Bachelor of Business Administration',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'PWD [0-0.2]',
#   'Sanskrit',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'PWD [0-0.2]',
#   'Sanskrit',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Ph.D.',
#   'Ph.D.-Doctor of Philosophy',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Kerala',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0.7-1.01]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Technical',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Gujarat',
#   'Hostel_available',
#   'M.E.-Master of Engineering',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.D.S.-Bachelor of Dental Surgery',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Ed.-Bachelor of Education',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Computer Application',
#   'Gujarat',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.7-1.01]',
#   'muslim [0.5-0.7]',
#   'other [0-0.2]'},
#  {'B.B.A.-Bachelor of Business Administration',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'M.Pharm. -Master of Pharmacy',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Technical',
#   'Telangana',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Karnataka',
#   'Medical',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.Ed. -Master of Education',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Technical',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Tripura',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.H.T.M.-Bachelor of Hotel and Tourism Management',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Hotel & Tourism Management',
#   'PWD [0-0.2]',
#   'Punjab',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'D.Pharma-Diploma in Pharmacy',
#   'Diploma',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Pharmacy',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.Pharm. -Master of Pharmacy',
#   'PWD [0-0.2]',
#   'Pharmacy',
#   'Post Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Computer Application',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0-0.2]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'Jammu and Kashmir',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Diploma',
#   'Diploma-Diploma',
#   'Gujarat',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Gujarat',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Diploma',
#   'Diploma-Diploma',
#   'Engineering & Technology',
#   'Gujarat',
# ...
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Ed.-Bachelor of Education',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.C.A.-Bachelor of Computer Applications',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Ph.D.',
#   'Ph.D.-Doctor of Philosophy',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Education/Teacher Education',
#   'Hostel_available',
#   'PG Diploma',
#   'PG Diploma-Post Graduate Diploma',
#   'PWD [0-0.2]',
#   'Punjab',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'M.Sc. Nursing-Master of Science in Nursing',
#   'Nursing',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0.7-1.01]'},
#  {'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Pharm. -Master of Pharmacy',
#   'Maharashtra',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Technical',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Chhatisgarh',
#   'Co-ed',
#   'Hostel_available',
#   'M.B.B.S.-Bachelor of Medicine and Bachelor of Surgery',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.7-1.01]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Assam',
#   'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Delhi',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'M.S.-Master of Science',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Punjab',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'Nursing',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.Com.-Master of Commerce',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Rajasthan',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Ed.-Bachelor of Education',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'Medical-Allopathy',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Mizoram',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0.7-1.01]'},
#  {'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.7-1.01]',
#   'Engineering & Technology',
#   'Girl_exclusive',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.2-0.5]',
#   'Girl_exclusive',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Hostel_available',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Karnataka',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Himachal Pradesh',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Technical',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'M.A.-Master of Arts',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0-0.2]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Telangana',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.2-0.5]',
#   'Chhatisgarh',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Chhatisgarh',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'M.Tech. -Master of Technology',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'Mizoram',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0.7-1.01]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Tripura',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Andhra Pradesh',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Tech. -Master of Technology',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Technical',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Andhra Pradesh',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Tech. -Master of Technology',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Technical',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.(Hons)-Bachelor of Arts (Honors)',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'West Bengal',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'West Bengal',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Ed.-Bachelor of Education',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Arts',
#   'B.A.-Bachelor of Arts',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Maharashtra',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'Uttar Pradesh',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.2-0.5]',
#   'Girl_exclusive',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PG Diploma',
#   'PG Diploma-Post Graduate Diploma',
#   'PWD [0-0.2]',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Rajasthan',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.E.-Bachelor of Engineering',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Tamil Nadu',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.7-1.01]',
#   'Co-ed',
#   'Hostel_available',
#   'M.E.-Master of Engineering',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Tamil Nadu',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Sc.(Nursing)-Bachelor of Science in Nursing',
#   'BC [0.5-0.7]',
#   'Co-ed',
#   'Hostel_available',
#   'Madhya Pradesh',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0.2-0.5]'},
#  {'B.Sc.-Bachelor of Science',
#   'BC [0-0.2]',
#   'Co-ed',
#   'Madhya Pradesh',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0-0.2]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0-0.2]',
#   'Co-ed',
#   'Hostel_available',
#   'M.E.-Master of Engineering',
#   'Maharashtra',
#   'No speciality',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.7-1.01]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'Assam',
#   'B.Sc.(Hons)-Bachelor of Science (Honors)',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Science',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0.2-0.5]',
#   'other [0-0.2]'},
#  {'B.Tech.-Bachelor of Technology',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Engineering & Technology',
#   'Hostel_available',
#   'Odisha',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.A.-Master of Arts',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.A.-Bachelor of Arts',
#   'BC [0.2-0.5]',
#   'Co-ed',
#   'Maharashtra',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.5-0.7]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'BC [0.5-0.7]',
#   'Co-ed',
#   'M.Sc.-Master of Science',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Post Graduate',
#   'Rajasthan',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  {'B.Com.-Bachelor of Commerce',
#   'BC [0.7-1.01]',
#   'Co-ed',
#   'Karnataka',
#   'No speciality',
#   'No_hostel',
#   'PWD [0-0.2]',
#   'Under Graduate',
#   'general [0.2-0.5]',
#   'muslim [0-0.2]',
#   'other [0-0.2]'},
#  ...]

# %%
## Run this is running only for lift calc on stored results
results = pd.read_csv("../results/apriori_latest.csv")

# %%
## If results exist as a variable in notebook
results = rules_df

# %%
results.columns = ["antecedent", "consequent", "confidence"]

# %%
set(list(ast.literal_eval(results["antecedent"][0]))).issubset(super_set[1])

# %%
def count_subsets(super_set, ant):
    c=0
    for s in super_set:
        if ant.issubset(s):
            c += 1
    return c

# %%
results["lift"] = None

# %%
def calc_lift(results, super_set):
    lift = []
    for row in tqdm(results.itertuples()):
        ant = set(list(ast.literal_eval(row.antecedent)))
        c = count_subsets(super_set, ant)
        lift.append(row.confidence / c)

# %%
lift = []
for row in tqdm(results.itertuples()):
    ant = set(list(ast.literal_eval(row.antecedent)))
    c = count_subsets(super_set, ant)
    lift.append(row.confidence / c)

# %%
results["lift"] = lift

# %%
results["lift"] *= len(df)

# %%
results.to_csv("../results/apriori_with_lift.csv", index=False)

# %% [markdown]
# ### Verify results using mlxtend library

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
columns_set_1 = ["levell", "programme", "total_general_total", "total_backward_castes_total", "pwd_total_persons", 
                "muslim_minority_total_persons", "other_minority_total_persons",
                 "state", "speciality", "girl_exclusive", "student_hostel_available"
                ]

# %%
apriori_df = df[columns_set_1].copy()
apriori_df.columns = ["level", "programme", "general", "BC", "PWD", "muslim", "other",
                     "state", "speciality", "girl_exclusive", "student_hostel_available"]

# %%
# Only run this when using mlxtend library :
apriori_df = one_hot_enc("programme", apriori_df)
apriori_df = one_hot_enc("level", apriori_df)
apriori_df = one_hot_enc("state", apriori_df)
apriori_df = one_hot_enc("speciality", apriori_df)
apriori_df = one_hot_enc("girl_exclusive", apriori_df)
apriori_df = one_hot_enc("student_hostel_available", apriori_df)

# %%
cols = ["general", "BC", "PWD", "muslim", "other"]
bins = [(0, 0.2), (0.2,0.5), (0.5,0.7), (0.7,1.01)]
apriori_df = binning(cols, apriori_df, bins)

# %%
# %%time
frequent_patterns = apriori(apriori_df, min_support=0.15, use_colnames=True)

# %%
frequent_patterns.sort_values(by="support", ascending=False)

# %%
# %%time
assoc_rules = association_rules(frequent_patterns, metric="confidence", min_threshold=0.6)

# %%
assoc_rules

# %%
rules.to_csv("../association_rules_sup_0.1_conf_0.6.csv", index=False)
